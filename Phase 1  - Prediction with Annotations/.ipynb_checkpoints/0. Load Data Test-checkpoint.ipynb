# %%
import pandas as pd

# %%
pd.read_table('subject_annotations.txt')
# Out:
#          SUBJID  GENDER    AGE  DTHHRDY
# 0     GTEX-N7MS       1  60-69      2.0
# 1     GTEX-NFK9       1  40-49      0.0
# 2     GTEX-NL3G       2  60-69      2.0
# 3     GTEX-NL4W       1  50-59      4.0
# 4     GTEX-NPJ7       2  60-69      4.0
# 5     GTEX-N7MT       2  60-69      4.0
# 6     GTEX-NL3H       1  60-69      3.0
# 7     GTEX-PLZ6       1  30-39      0.0
# 8     GTEX-O5YT       1  20-29      0.0
# 9     GTEX-NPJ8       1  40-49      4.0
# 10    GTEX-OXRO       2  60-69      4.0
# 11    GTEX-RVPV       1  60-69      3.0
# 12    GTEX-O5YV       2  60-69      3.0
# 13    GTEX-OHPJ       1  60-69      0.0
# 14    GTEX-O5YU       1  60-69      4.0
# 15    GTEX-OHPK       2  50-59      0.0
# 16    GTEX-O5YW       1  50-59      0.0
# 17    GTEX-OHPL       2  60-69      0.0
# 18    GTEX-OHPN       2  60-69      0.0
# 19    GTEX-OHPM       1  50-59      0.0
# 20    GTEX-OIZG       1  50-59      0.0
# 21    GTEX-OIZF       1  60-69      0.0
# ...

# %%
pd.read_table('sample_annotations.txt')
# Out:
#                          SAMPID  SMATSSCR SMCENTER  \
# 0      GTEX-1117F-0003-SM-58Q7G       NaN       B1
# 1      GTEX-1117F-0003-SM-5DWSB       NaN       B1
# 2      GTEX-1117F-0226-SM-5GZZ7       0.0       B1
# 3      GTEX-1117F-0426-SM-5EGHI       0.0       B1
# 4      GTEX-1117F-0526-SM-5EGHJ       0.0       B1
# 5      GTEX-1117F-0626-SM-5N9CS       1.0       B1
# 6      GTEX-1117F-0726-SM-5GIEN       1.0       B1
# 7      GTEX-1117F-1326-SM-5EGHH       1.0       B1
# 8      GTEX-1117F-2226-SM-5N9CH       1.0       B1
# 9      GTEX-1117F-2426-SM-5EGGH       1.0       B1
# 10     GTEX-1117F-2526-SM-5GZY6       2.0       B1
# 11     GTEX-1117F-2826-SM-5GZXL       1.0       B1
# 12     GTEX-1117F-2926-SM-5GZYI       0.0       B1
# 13     GTEX-1117F-3026-SM-5GZYU       1.0       B1
# 14     GTEX-1117F-3226-SM-5N9CT       1.0       B1
# 15     GTEX-111CU-0003-SM-58Q95       NaN       B1
# 16     GTEX-111CU-0003-SM-5DWTR       NaN       B1
# ...
