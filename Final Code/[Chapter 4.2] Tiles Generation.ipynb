# %%
from glob import glob
import os as os
import matplotlib.pyplot as plt  
import matplotlib as mpl  
import numpy as np  
import openslide  
from openslide import open_slide  
from openslide.deepzoom import DeepZoomGenerator  
import pandas as pd
import scipy as scipy
# %matplotlib inline

import skimage.io
import skimage.measure
import skimage.color

import matplotlib.patches as mpatches

import histomicstk as htk

from scipy.ndimage.morphology import binary_fill_holes, binary_closing, binary_dilation  

plt.rcParams['figure.figsize'] = (10, 6)

# %%
directories = [name for name in os.listdir("/home/a0121533/fyp2017dsap/slides/") if os.path.isdir(os.path.join("/home/a0121533/fyp2017dsap/slides/", name))]
slide_files = []

for d in directories:
    slide_path = "/home/a0121533/fyp2017dsap/slides/" + d + "/" 
    list_of_slides = glob(slide_path + "*.svs")
    
    if len(list_of_slides) != 0:
        slide_file_name = glob(slide_path + "*.svs")[0] # one slide in each directory
        slide_files.append(slide_file_name)

# %%
#sanity check
print(len(directories))
# Out:
# 327

# %%
#split train / test data
n_slides = len(slide_files)
n_train = int(n_slides * 0.7)
slides_train = slide_files[:n_train]
slides_test = slide_files[n_train:]

# %%
tile_size = 128
default_slide_level = 12

# %%
def not_mostly_white(tile, threshold_x):
    ''' 
    Returns true if more than X% of slide pixels are not white
    '''
    pixels = tile.getdata()
    white_thresh = (240,240,240)
    not_white = 0
    for pixel in pixels:        
        if pixel < white_thresh:
            not_white += 1
        else:
            print(pixel)
    return (not_white /len(pixels)) > threshold_x

# Load reference image for normalization
refImageFile = ('https://data.kitware.com/api/v1/file/'
                '57718cc28d777f1ecd8a883c/download')  # L1.png

imReference = skimage.io.imread(refImageFile)[:, :, :3]

# get mean and stddev of reference image in lab space
meanRef, stdRef = htk.preprocessing.color_conversion.lab_mean_std(imReference)


def normalize_slide(imInput):
    # perform reinhard color normalization
    imNmzd = htk.preprocessing.color_normalization.reinhard(imInput, meanRef, stdRef)
    return imNmzd

def find_nth(haystack, needle, n):
    start = haystack.find(needle)
    while start >= 0 and n > 1:
        start = haystack.find(needle, start+len(needle))
        n -= 1
    return start

# %%
def create_tiles(slide_files, threshold_x, slide_type):
    num_slides = len(slide_files)
    print("num_slides: " + str(num_slides))
    
    write_slides_path = "/home/a0121533/fyp2017dsap/tiles/temp/" + slide_type + "/"
    
    counter = 0
    invalid_slides = []
    tiles_matrix = []
    patient_id_list = []
    
    for s in slide_files:
        counter += 1
        slide_index = 0
        tiles_created = False
        
        try:           
            print("######### Opening Slide:", str(counter),"/", num_slides,"\n")
            slide = open_slide(s)  
            slide_id = s[s.rfind('/')+1:s.find('.')]
            patient_id = s[s.rfind('/')+1:s.rfind('/')+13]

            tiles = DeepZoomGenerator(slide, tile_size=tile_size, overlap=0, limit_bounds=False)  
            # overlap: adds pixels to each side

            print("Level tiles for default level: " + str(tiles.level_tiles[default_slide_level])) 
            # See how many tiles there are for default slide level of magnification.

            tiles_x = tiles.level_tiles[default_slide_level][0]
            tiles_y = tiles.level_tiles[default_slide_level][1] 

            # iterate through slide level rows and columns
            for i in range(tiles_x):
                for j in range(tiles_y):
                    tile = tiles.get_tile(default_slide_level, (i,j))
                    if tile.size == (tile_size, tile_size) and not_mostly_white(tile, threshold_x):
                        slide_index += 1
                        normalized = normalize_slide(np.asarray(tile))
                        tiles_matrix.append(normalized)                        
                        tiles_created = True
                        tile_name = write_slides_path + slide_id + "_" + str(slide_index) + ".png"
                        tile.save(tile_name, "PNG")      
            print("######### Closing Slide")
            slide.close()
            
            if tiles_created:
                patient_id_list.append(patient_id)
                
        except OSError:
            invalid_slides.append(s)
    return tiles_matrix, invalid_slides, patient_id_list

# %%
train_tiles, invalid_train, train_patient_id_list = create_tiles(slides_train, 0.98, "train")
# Out:
# num_slides: 228
# ######### Opening Slide: 1 / 228
#
# Level tiles for default level: (12, 9)
# ######### Closing Slide
# ######### Opening Slide: 2 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 3 / 228
#
# Level tiles for default level: (10, 11)
# ######### Closing Slide
# ######### Opening Slide: 4 / 228
#
# Level tiles for default level: (8, 9)
# ######### Closing Slide
# ######### Opening Slide: 5 / 228
#
# Level tiles for default level: (12, 9)
# ######### Closing Slide
# ######### Opening Slide: 6 / 228
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 7 / 228
#
# Level tiles for default level: (13, 4)
# ######### Closing Slide
# ######### Opening Slide: 8 / 228
#
# Level tiles for default level: (11, 11)
# ######### Closing Slide
# ######### Opening Slide: 9 / 228
#
# Level tiles for default level: (13, 12)
# ######### Closing Slide
# ######### Opening Slide: 10 / 228
#
# Level tiles for default level: (14, 12)
# ######### Closing Slide
# ######### Opening Slide: 11 / 228
#
# Level tiles for default level: (15, 15)
# ######### Closing Slide
# ######### Opening Slide: 12 / 228
#
# Level tiles for default level: (12, 3)
# ######### Closing Slide
# ######### Opening Slide: 13 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 14 / 228
#
# Level tiles for default level: (14, 11)
# ######### Closing Slide
# ######### Opening Slide: 15 / 228
#
# Level tiles for default level: (12, 6)
# ######### Closing Slide
# ######### Opening Slide: 16 / 228
#
# Level tiles for default level: (12, 12)
# ######### Closing Slide
# ######### Opening Slide: 17 / 228
#
# Level tiles for default level: (13, 12)
# ######### Closing Slide
# ######### Opening Slide: 18 / 228
#
# Level tiles for default level: (10, 8)
# ######### Closing Slide
# ######### Opening Slide: 19 / 228
#
# Level tiles for default level: (12, 6)
# ######### Closing Slide
# ######### Opening Slide: 20 / 228
#
# Level tiles for default level: (6, 9)
# ######### Closing Slide
# ######### Opening Slide: 21 / 228
#
# Level tiles for default level: (4, 9)
# ######### Closing Slide
# ######### Opening Slide: 22 / 228
#
# Level tiles for default level: (12, 3)
# ######### Closing Slide
# ######### Opening Slide: 23 / 228
#
# Level tiles for default level: (11, 9)
# ######### Closing Slide
# ######### Opening Slide: 24 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 25 / 228
#
# Level tiles for default level: (11, 5)
# ######### Closing Slide
# ######### Opening Slide: 26 / 228
#
# Level tiles for default level: (16, 12)
# ######### Closing Slide
# ######### Opening Slide: 27 / 228
#
# Level tiles for default level: (15, 15)
# ######### Closing Slide
# ######### Opening Slide: 28 / 228
#
# Level tiles for default level: (10, 11)
# ######### Closing Slide
# ######### Opening Slide: 29 / 228
#
# Level tiles for default level: (12, 9)
# ######### Closing Slide
# ######### Opening Slide: 30 / 228
#
# Level tiles for default level: (10, 6)
# ######### Closing Slide
# ######### Opening Slide: 31 / 228
#
# Level tiles for default level: (10, 6)
# ######### Closing Slide
# ######### Opening Slide: 32 / 228
#
# Level tiles for default level: (10, 15)
# ######### Closing Slide
# ######### Opening Slide: 33 / 228
#
# Level tiles for default level: (16, 14)
# ######### Closing Slide
# ######### Opening Slide: 34 / 228
#
# Level tiles for default level: (14, 12)
# ######### Closing Slide
# ######### Opening Slide: 35 / 228
#
# Level tiles for default level: (16, 13)
# ######### Closing Slide
# ######### Opening Slide: 36 / 228
#
# Level tiles for default level: (14, 9)
# ######### Closing Slide
# ######### Opening Slide: 37 / 228
#
# Level tiles for default level: (9, 6)
# ######### Closing Slide
# ######### Opening Slide: 38 / 228
#
# Level tiles for default level: (16, 13)
# ######### Closing Slide
# ######### Opening Slide: 39 / 228
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 40 / 228
#
# Level tiles for default level: (16, 12)
# ######### Closing Slide
# ######### Opening Slide: 41 / 228
#
# Level tiles for default level: (16, 9)
# ######### Closing Slide
# ######### Opening Slide: 42 / 228
#
# Level tiles for default level: (11, 3)
# ######### Closing Slide
# ######### Opening Slide: 43 / 228
#
# Level tiles for default level: (9, 9)
# ######### Closing Slide
# ######### Opening Slide: 44 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 45 / 228
#
# Level tiles for default level: (16, 7)
# ######### Closing Slide
# ######### Opening Slide: 46 / 228
#
# Level tiles for default level: (13, 9)
# ######### Closing Slide
# ######### Opening Slide: 47 / 228
#
# Level tiles for default level: (10, 8)
# ######### Closing Slide
# ######### Opening Slide: 48 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 49 / 228
#
# Level tiles for default level: (13, 5)
# ######### Closing Slide
# ######### Opening Slide: 50 / 228
#
# Level tiles for default level: (12, 5)
# ######### Closing Slide
# ######### Opening Slide: 51 / 228
#
# Level tiles for default level: (12, 10)
# ######### Closing Slide
# ######### Opening Slide: 52 / 228
#
# Level tiles for default level: (10, 12)
# ######### Closing Slide
# ######### Opening Slide: 53 / 228
#
# Level tiles for default level: (12, 7)
# ######### Closing Slide
# ######### Opening Slide: 54 / 228
#
# Level tiles for default level: (9, 7)
# ######### Closing Slide
# ######### Opening Slide: 55 / 228
#
# Level tiles for default level: (7, 9)
# ######### Closing Slide
# ######### Opening Slide: 56 / 228
#
# Level tiles for default level: (7, 9)
# ######### Closing Slide
# ######### Opening Slide: 57 / 228
#
# Level tiles for default level: (7, 9)
# ######### Closing Slide
# ######### Opening Slide: 58 / 228
#
# Level tiles for default level: (15, 15)
# ######### Closing Slide
# ######### Opening Slide: 59 / 228
#
# Level tiles for default level: (11, 6)
# ######### Closing Slide
# ######### Opening Slide: 60 / 228
#
# Level tiles for default level: (16, 16)
# ######### Closing Slide
# ######### Opening Slide: 61 / 228
#
# Level tiles for default level: (9, 5)
# ######### Closing Slide
# ######### Opening Slide: 62 / 228
#
# Level tiles for default level: (12, 4)
# ######### Closing Slide
# ######### Opening Slide: 63 / 228
#
# Level tiles for default level: (11, 10)
# ######### Closing Slide
# ######### Opening Slide: 64 / 228
#
# Level tiles for default level: (12, 5)
# ######### Closing Slide
# ######### Opening Slide: 65 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 66 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 67 / 228
#
# Level tiles for default level: (12, 12)
# ######### Closing Slide
# ######### Opening Slide: 68 / 228
#
# Level tiles for default level: (14, 12)
# ######### Closing Slide
# ######### Opening Slide: 69 / 228
#
# Level tiles for default level: (11, 6)
# ######### Closing Slide
# ######### Opening Slide: 70 / 228
#
# Level tiles for default level: (14, 14)
# ######### Closing Slide
# ######### Opening Slide: 71 / 228
#
# Level tiles for default level: (11, 6)
# ######### Closing Slide
# ######### Opening Slide: 72 / 228
#
# Level tiles for default level: (15, 15)
# ######### Closing Slide
# ######### Opening Slide: 73 / 228
#
# Level tiles for default level: (10, 12)
# ######### Closing Slide
# ######### Opening Slide: 74 / 228
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 75 / 228
#
# Level tiles for default level: (9, 6)
# ######### Closing Slide
# ######### Opening Slide: 76 / 228
#
# Level tiles for default level: (13, 13)
# ######### Closing Slide
# ######### Opening Slide: 77 / 228
#
# Level tiles for default level: (8, 10)
# ######### Closing Slide
# ######### Opening Slide: 78 / 228
#
# Level tiles for default level: (6, 9)
# ######### Closing Slide
# ######### Opening Slide: 79 / 228
#
# Level tiles for default level: (10, 11)
# ######### Closing Slide
# ######### Opening Slide: 80 / 228
#
# Level tiles for default level: (9, 9)
# ######### Closing Slide
# ######### Opening Slide: 81 / 228
#
# Level tiles for default level: (10, 9)
# ######### Closing Slide
# ######### Opening Slide: 82 / 228
#
# Level tiles for default level: (11, 10)
# ######### Closing Slide
# ######### Opening Slide: 83 / 228
#
# Level tiles for default level: (12, 8)
# ######### Closing Slide
# ######### Opening Slide: 84 / 228
#
# Level tiles for default level: (13, 16)
# ######### Closing Slide
# ######### Opening Slide: 85 / 228
#
# Level tiles for default level: (12, 11)
# ######### Closing Slide
# ######### Opening Slide: 86 / 228
#
# Level tiles for default level: (9, 13)
# ######### Closing Slide
# ######### Opening Slide: 87 / 228
#
# Level tiles for default level: (12, 10)
# ######### Closing Slide
# ######### Opening Slide: 88 / 228
#
# Level tiles for default level: (9, 10)
# ######### Closing Slide
# ######### Opening Slide: 89 / 228
#
# Level tiles for default level: (12, 12)
# ######### Closing Slide
# ######### Opening Slide: 90 / 228
#
# Level tiles for default level: (10, 15)
# ######### Closing Slide
# ######### Opening Slide: 91 / 228
#
# Level tiles for default level: (9, 4)
# ######### Closing Slide
# ######### Opening Slide: 92 / 228
#
# Level tiles for default level: (7, 11)
# ######### Closing Slide
# ######### Opening Slide: 93 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 94 / 228
#
# Level tiles for default level: (10, 10)
# ######### Closing Slide
# ######### Opening Slide: 95 / 228
#
# Level tiles for default level: (10, 10)
# ######### Closing Slide
# ######### Opening Slide: 96 / 228
#
# Level tiles for default level: (12, 11)
# ######### Closing Slide
# ######### Opening Slide: 97 / 228
#
# Level tiles for default level: (11, 9)
# ######### Closing Slide
# ######### Opening Slide: 98 / 228
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 99 / 228
#
# Level tiles for default level: (12, 8)
# ######### Closing Slide
# ######### Opening Slide: 100 / 228
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 101 / 228
#
# Level tiles for default level: (9, 6)
# ######### Closing Slide
# ######### Opening Slide: 102 / 228
#
# Level tiles for default level: (9, 11)
# ######### Closing Slide
# ######### Opening Slide: 103 / 228
#
# Level tiles for default level: (16, 6)
# ######### Closing Slide
# ######### Opening Slide: 104 / 228
#
# Level tiles for default level: (10, 7)
# ######### Closing Slide
# ######### Opening Slide: 105 / 228
#
# Level tiles for default level: (8, 11)
# ######### Closing Slide
# ######### Opening Slide: 106 / 228
#
# Level tiles for default level: (16, 16)
# ######### Closing Slide
# ######### Opening Slide: 107 / 228
#
# Level tiles for default level: (14, 6)
# ######### Closing Slide
# ######### Opening Slide: 108 / 228
#
# Level tiles for default level: (10, 9)
# ######### Closing Slide
# ######### Opening Slide: 109 / 228
#
# Level tiles for default level: (12, 4)
# ######### Closing Slide
# ######### Opening Slide: 110 / 228
#
# Level tiles for default level: (6, 9)
# ######### Closing Slide
# ######### Opening Slide: 111 / 228
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 112 / 228
#
# Level tiles for default level: (16, 12)
# ######### Closing Slide
# ######### Opening Slide: 113 / 228
#
# Level tiles for default level: (13, 10)
# ######### Closing Slide
# ######### Opening Slide: 114 / 228
#
# Level tiles for default level: (16, 15)
# ######### Closing Slide
# ######### Opening Slide: 115 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 116 / 228
#
# Level tiles for default level: (13, 10)
# ######### Closing Slide
# ######### Opening Slide: 117 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 118 / 228
#
# Level tiles for default level: (10, 6)
# ######### Closing Slide
# ######### Opening Slide: 119 / 228
#
# Level tiles for default level: (10, 14)
# ######### Closing Slide
# ######### Opening Slide: 120 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 121 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 122 / 228
#
# Level tiles for default level: (13, 6)
# ######### Closing Slide
# ######### Opening Slide: 123 / 228
#
# Level tiles for default level: (12, 8)
# ######### Closing Slide
# ######### Opening Slide: 124 / 228
#
# Level tiles for default level: (11, 7)
# ######### Closing Slide
# ######### Opening Slide: 125 / 228
#
# Level tiles for default level: (11, 13)
# ######### Closing Slide
# ######### Opening Slide: 126 / 228
#
# Level tiles for default level: (12, 9)
# ######### Closing Slide
# ######### Opening Slide: 127 / 228
#
# Level tiles for default level: (12, 5)
# ######### Closing Slide
# ######### Opening Slide: 128 / 228
#
# Level tiles for default level: (13, 7)
# ######### Closing Slide
# ######### Opening Slide: 129 / 228
#
# Level tiles for default level: (10, 6)
# ######### Closing Slide
# ######### Opening Slide: 130 / 228
#
# Level tiles for default level: (9, 3)
# ######### Closing Slide
# ######### Opening Slide: 131 / 228
#
# Level tiles for default level: (9, 6)
# ######### Closing Slide
# ######### Opening Slide: 132 / 228
#
# Level tiles for default level: (12, 3)
# ######### Closing Slide
# ######### Opening Slide: 133 / 228
#
# Level tiles for default level: (13, 4)
# ######### Closing Slide
# ######### Opening Slide: 134 / 228
#
# Level tiles for default level: (15, 13)
# ######### Closing Slide
# ######### Opening Slide: 135 / 228
#
# Level tiles for default level: (14, 16)
# ######### Closing Slide
# ######### Opening Slide: 136 / 228
#
# Level tiles for default level: (11, 3)
# ######### Closing Slide
# ######### Opening Slide: 137 / 228
#
# Level tiles for default level: (9, 7)
# ######### Closing Slide
# ######### Opening Slide: 138 / 228
#
# Level tiles for default level: (7, 11)
# ######### Closing Slide
# ######### Opening Slide: 139 / 228
#
# Level tiles for default level: (14, 7)
# ######### Closing Slide
# ######### Opening Slide: 140 / 228
#
# Level tiles for default level: (9, 6)
# ######### Closing Slide
# ######### Opening Slide: 141 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 142 / 228
#
# Level tiles for default level: (11, 12)
# ######### Closing Slide
# ######### Opening Slide: 143 / 228
#
# Level tiles for default level: (9, 14)
# ######### Closing Slide
# ######### Opening Slide: 144 / 228
#
# Level tiles for default level: (11, 7)
# ######### Closing Slide
# ######### Opening Slide: 145 / 228
#
# Level tiles for default level: (9, 9)
# ######### Closing Slide
# ######### Opening Slide: 146 / 228
#
# Level tiles for default level: (11, 9)
# ######### Closing Slide
# ######### Opening Slide: 147 / 228
#
# Level tiles for default level: (11, 8)
# ######### Closing Slide
# ######### Opening Slide: 148 / 228
#
# Level tiles for default level: (10, 5)
# ######### Closing Slide
# ######### Opening Slide: 149 / 228
#
# Level tiles for default level: (10, 16)
# ######### Closing Slide
# ######### Opening Slide: 150 / 228
#
# Level tiles for default level: (15, 8)
# ######### Closing Slide
# ######### Opening Slide: 151 / 228
#
# Level tiles for default level: (11, 9)
# ######### Closing Slide
# ######### Opening Slide: 152 / 228
#
# Level tiles for default level: (16, 5)
# ######### Closing Slide
# ######### Opening Slide: 153 / 228
#
# Level tiles for default level: (9, 10)
# ######### Closing Slide
# ######### Opening Slide: 154 / 228
#
# Level tiles for default level: (14, 13)
# ######### Closing Slide
# ######### Opening Slide: 155 / 228
#
# Level tiles for default level: (10, 3)
# ######### Closing Slide
# ######### Opening Slide: 156 / 228
#
# Level tiles for default level: (12, 10)
# ######### Closing Slide
# ######### Opening Slide: 157 / 228
#
# Level tiles for default level: (10, 6)
# ######### Closing Slide
# ######### Opening Slide: 158 / 228
#
# Level tiles for default level: (9, 8)
# ######### Closing Slide
# ######### Opening Slide: 159 / 228
#
# Level tiles for default level: (11, 5)
# ######### Closing Slide
# ######### Opening Slide: 160 / 228
#
# Level tiles for default level: (12, 5)
# ######### Closing Slide
# ######### Opening Slide: 161 / 228
#
# Level tiles for default level: (9, 5)
# ######### Closing Slide
# ######### Opening Slide: 162 / 228
#
# Level tiles for default level: (15, 14)
# ######### Closing Slide
# ######### Opening Slide: 163 / 228
#
# Level tiles for default level: (10, 8)
# ######### Closing Slide
# ######### Opening Slide: 164 / 228
#
# Level tiles for default level: (9, 7)
# ######### Closing Slide
# ######### Opening Slide: 165 / 228
#
# Level tiles for default level: (14, 8)
# ######### Closing Slide
# ######### Opening Slide: 166 / 228
#
# Level tiles for default level: (11, 3)
# ######### Closing Slide
# ######### Opening Slide: 167 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 168 / 228
#
# Level tiles for default level: (10, 13)
# ######### Closing Slide
# ######### Opening Slide: 169 / 228
#
# Level tiles for default level: (10, 7)
# ######### Closing Slide
# ######### Opening Slide: 170 / 228
#
# Level tiles for default level: (10, 8)
# ######### Closing Slide
# ######### Opening Slide: 171 / 228
#
# Level tiles for default level: (9, 9)
# ######### Closing Slide
# ######### Opening Slide: 172 / 228
#
# Level tiles for default level: (7, 12)
# ######### Closing Slide
# ######### Opening Slide: 173 / 228
#
# Level tiles for default level: (10, 6)
# ######### Closing Slide
# ######### Opening Slide: 174 / 228
#
# Level tiles for default level: (7, 9)
# ######### Closing Slide
# ######### Opening Slide: 175 / 228
#
# Level tiles for default level: (10, 8)
# ######### Closing Slide
# ######### Opening Slide: 176 / 228
#
# Level tiles for default level: (10, 3)
# ######### Closing Slide
# ######### Opening Slide: 177 / 228
#
# Level tiles for default level: (10, 2)
# ######### Closing Slide
# ######### Opening Slide: 178 / 228
#
# Level tiles for default level: (7, 11)
# ######### Closing Slide
# ######### Opening Slide: 179 / 228
#
# Level tiles for default level: (16, 11)
# ######### Closing Slide
# ######### Opening Slide: 180 / 228
#
# Level tiles for default level: (15, 13)
# ######### Closing Slide
# ######### Opening Slide: 181 / 228
#
# Level tiles for default level: (11, 3)
# ######### Closing Slide
# ######### Opening Slide: 182 / 228
#
# Level tiles for default level: (12, 14)
# ######### Closing Slide
# ######### Opening Slide: 183 / 228
#
# Level tiles for default level: (11, 14)
# ######### Closing Slide
# ######### Opening Slide: 184 / 228
#
# Level tiles for default level: (10, 8)
# ######### Closing Slide
# ######### Opening Slide: 185 / 228
#
# Level tiles for default level: (16, 9)
# ######### Closing Slide
# ######### Opening Slide: 186 / 228
#
# Level tiles for default level: (16, 13)
# ######### Closing Slide
# ######### Opening Slide: 187 / 228
#
# Level tiles for default level: (13, 8)
# ######### Closing Slide
# ######### Opening Slide: 188 / 228
#
# Level tiles for default level: (15, 11)
# ######### Closing Slide
# ######### Opening Slide: 189 / 228
#
# Level tiles for default level: (16, 13)
# ######### Closing Slide
# ######### Opening Slide: 190 / 228
#
# Level tiles for default level: (12, 13)
# ######### Closing Slide
# ######### Opening Slide: 191 / 228
#
# Level tiles for default level: (15, 15)
# ######### Closing Slide
# ######### Opening Slide: 192 / 228
#
# Level tiles for default level: (16, 3)
# ######### Closing Slide
# ######### Opening Slide: 193 / 228
#
# Level tiles for default level: (9, 4)
# ######### Closing Slide
# ######### Opening Slide: 194 / 228
#
# Level tiles for default level: (9, 3)
# ######### Closing Slide
# ######### Opening Slide: 195 / 228
#
# Level tiles for default level: (7, 9)
# ######### Closing Slide
# ######### Opening Slide: 196 / 228
#
# Level tiles for default level: (9, 4)
# ######### Closing Slide
# ######### Opening Slide: 197 / 228
#
# Level tiles for default level: (16, 10)
# ######### Closing Slide
# ######### Opening Slide: 198 / 228
#
# Level tiles for default level: (16, 13)
# ######### Closing Slide
# ######### Opening Slide: 199 / 228
#
# Level tiles for default level: (9, 3)
# ######### Closing Slide
# ######### Opening Slide: 200 / 228
#
# Level tiles for default level: (12, 4)
# ######### Closing Slide
# ######### Opening Slide: 201 / 228
#
# Level tiles for default level: (14, 12)
# ######### Closing Slide
# ######### Opening Slide: 202 / 228
#
# Level tiles for default level: (13, 5)
# ######### Closing Slide
# ######### Opening Slide: 203 / 228
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 204 / 228
#
# Level tiles for default level: (11, 7)
# ######### Closing Slide
# ######### Opening Slide: 205 / 228
#
# Level tiles for default level: (13, 16)
# ######### Closing Slide
# ######### Opening Slide: 206 / 228
#
# Level tiles for default level: (11, 16)
# ######### Closing Slide
# ######### Opening Slide: 207 / 228
#
# Level tiles for default level: (16, 16)
# ######### Closing Slide
# ######### Opening Slide: 208 / 228
#
# Level tiles for default level: (12, 12)
# ######### Closing Slide
# ######### Opening Slide: 209 / 228
#
# Level tiles for default level: (13, 4)
# ######### Closing Slide
# ######### Opening Slide: 210 / 228
#
# Level tiles for default level: (9, 6)
# ######### Closing Slide
# ######### Opening Slide: 211 / 228
#
# Level tiles for default level: (9, 10)
# ######### Closing Slide
# ######### Opening Slide: 212 / 228
#
# Level tiles for default level: (13, 4)
# ######### Closing Slide
# ######### Opening Slide: 213 / 228
#
# Level tiles for default level: (9, 10)
# ######### Closing Slide
# ######### Opening Slide: 214 / 228
#
# Level tiles for default level: (9, 9)
# ######### Closing Slide
# ######### Opening Slide: 215 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 216 / 228
#
# Level tiles for default level: (10, 5)
# ######### Closing Slide
# ######### Opening Slide: 217 / 228
#
# Level tiles for default level: (11, 13)
# ######### Closing Slide
# ######### Opening Slide: 218 / 228
#
# Level tiles for default level: (11, 4)
# ######### Closing Slide
# ######### Opening Slide: 219 / 228
#
# Level tiles for default level: (14, 14)
# ######### Closing Slide
# ######### Opening Slide: 220 / 228
#
# Level tiles for default level: (12, 12)
# ######### Closing Slide
# ######### Opening Slide: 221 / 228
#
# Level tiles for default level: (7, 9)
# ######### Closing Slide
# ######### Opening Slide: 222 / 228
#
# Level tiles for default level: (14, 14)
# ######### Closing Slide
# ######### Opening Slide: 223 / 228
#
# Level tiles for default level: (15, 12)
# ######### Closing Slide
# ######### Opening Slide: 224 / 228
#
# Level tiles for default level: (14, 10)
# ######### Closing Slide
# ######### Opening Slide: 225 / 228
#
# Level tiles for default level: (13, 5)
# ######### Closing Slide
# ######### Opening Slide: 226 / 228
#
# Level tiles for default level: (12, 14)
# ######### Closing Slide
# ######### Opening Slide: 227 / 228
#
# Level tiles for default level: (16, 12)
# ######### Closing Slide
# ######### Opening Slide: 228 / 228
#
# Level tiles for default level: (8, 10)
# ######### Closing Slide

# %%
test_tiles, invalid_test, test_patient_id_list = create_tiles(slides_test, 0.98, "test")
# Out:
# num_slides: 99
# ######### Opening Slide: 1 / 99
#
# Level tiles for default level: (10, 12)
# ######### Closing Slide
# ######### Opening Slide: 2 / 99
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 3 / 99
#
# Level tiles for default level: (16, 5)
# ######### Closing Slide
# ######### Opening Slide: 4 / 99
#
# Level tiles for default level: (7, 12)
# ######### Closing Slide
# ######### Opening Slide: 5 / 99
#
# Level tiles for default level: (6, 9)
# ######### Closing Slide
# ######### Opening Slide: 6 / 99
#
# Level tiles for default level: (10, 4)
# ######### Closing Slide
# ######### Opening Slide: 7 / 99
#
# Level tiles for default level: (16, 16)
# ######### Closing Slide
# ######### Opening Slide: 8 / 99
#
# Level tiles for default level: (11, 10)
# ######### Closing Slide
# ######### Opening Slide: 9 / 99
#
# Level tiles for default level: (10, 10)
# ######### Closing Slide
# ######### Opening Slide: 10 / 99
#
# Level tiles for default level: (10, 7)
# ######### Closing Slide
# ######### Opening Slide: 11 / 99
#
# Level tiles for default level: (15, 7)
# ######### Closing Slide
# ######### Opening Slide: 12 / 99
#
# Level tiles for default level: (10, 10)
# ######### Closing Slide
# ######### Opening Slide: 13 / 99
#
# Level tiles for default level: (10, 6)
# ######### Closing Slide
# ######### Opening Slide: 14 / 99
#
# Level tiles for default level: (14, 7)
# ######### Closing Slide
# ######### Opening Slide: 15 / 99
#
# Level tiles for default level: (9, 10)
# ######### Closing Slide
# ######### Opening Slide: 16 / 99
#
# Level tiles for default level: (11, 10)
# ######### Closing Slide
# ######### Opening Slide: 17 / 99
#
# Level tiles for default level: (9, 12)
