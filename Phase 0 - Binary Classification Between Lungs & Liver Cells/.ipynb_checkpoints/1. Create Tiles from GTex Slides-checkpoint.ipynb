# %%
from glob import glob
import os as os
import matplotlib.pyplot as plt  
import matplotlib as mpl  
import numpy as np  
import openslide  
from openslide import open_slide  
from openslide.deepzoom import DeepZoomGenerator  
import pandas as pd
import scipy as scipy

from scipy.ndimage.morphology import binary_fill_holes, binary_closing, binary_dilation  

plt.rcParams['figure.figsize'] = (10, 6)

# %%
tile_size = 128
default_slide_level = 12 # set to 12 by default

subject_annotations = pd.read_table('subject_annotations.txt')
sample_annotations = pd.read_table('sample_annotations.txt')

sample_id_list = sample_annotations['SAMPID']
sample_id_dict = {}

# Create dictionary of slide names and corresponding index in sample annotations txt
for i in range(0, len(sample_id_list)):
    sample_id = sample_id_list[i]
    sample_id_shortened = sample_id[0:sample_id.rfind("-", 0, sample_id.rfind("-"))]
    sample_id_dict[sample_id_shortened] = i

# %%
def not_mostly_white(tile, threshold_x):
    ''' 
    Returns true if more than X% of slide pixels are not white
    '''
    pixels = tile.getdata()
    white_thresh = (240,240,240)
    not_white = 0
    for pixel in pixels:        
        if pixel < white_thresh:
            not_white += 1
    return (not_white /len(pixels)) > threshold_x

# %%
def create_tiles(data_type, slide_type, threshold_x):
    '''
    .svs files are read with openslide library
    and are sliced into tiles (png) at default slide level: 12
    '''
    read_slides_path = "slides/" + data_type + "/" + slide_type + "s/"
    write_slides_path = "data/" + data_type + "/" + slide_type + "s/"
    
    invalid_slides = []
    
    slides = glob(read_slides_path + "*.svs")  
    #print("Slides: " + str(slides) + "\n")
    num_slides = len(slides)
    print("num_slides: " + str(num_slides))
    
    num_saved = 0
    
    for slide_num in range(num_slides):
        slide_index = 0
        s = slides[slide_num]
        slide_name = s[s.rfind('/')+1:s.rfind('.')]
        
        try:
            row_index = sample_id_dict[slide_name]
            # get Intragenic Rate: The fraction of reads that map within genes (within introns or exons)
            SMNTRART = sample_annotations.iloc[[row_index]]['SMNTRART'].values[0]
            
            if (SMNTRART > float(0)):
                print("######### Opening Slide:" + slide_name + "\n")
                slide = open_slide(s)  

                slide_directory = write_slides_path + slide_name 

                tiles = DeepZoomGenerator(slide, tile_size=tile_size, overlap=0, limit_bounds=False)  
                # overlap: adds pixels to each side

                print("Level tiles for default level: " + str(tiles.level_tiles[default_slide_level])) 
                # See how many tiles there are for default slide level of magnification.

                tiles_x = tiles.level_tiles[default_slide_level][0]
                tiles_y = tiles.level_tiles[default_slide_level][1] 

                # iterate through slide level rows and columns
                for i in range(tiles_x):
                    for j in range(tiles_y):
                        tile = tiles.get_tile(default_slide_level, (i,j))
                        if tile.size == (tile_size, tile_size) and not_mostly_white(tile, threshold_x):
                            slide_index += 1
                            num_saved += 1
                            tile_name = slide_directory + "_" + str(slide_index) + ".png"
                            tile.save(tile_name, "PNG")      
                print("######### Closing Slide:" + slides[slide_num] + "\n")
                slide.close()
        except KeyError:
            invalid_slides.append(slide_name)
    return invalid_slides

# %%
invalid_lung_validation_slides = create_tiles("validation", "lung", 0.8)
print(invalid_lung_validation_slides)
# Out:
# num_slides: 15
# ######### Opening Slide:GTEX-13O3O-0726
#
# Level tiles for default level: (22, 12)
# ######### Closing Slide:slides/validation/lungs/GTEX-13O3O-0726.svs
#
# ######### Opening Slide:GTEX-13JUV-0526
#
# Level tiles for default level: (26, 19)
# ######### Closing Slide:slides/validation/lungs/GTEX-13JUV-0526.svs
#
# ######### Opening Slide:GTEX-13O21-3026
#
# Level tiles for default level: (17, 9)
# ######### Closing Slide:slides/validation/lungs/GTEX-13O21-3026.svs
#
# ######### Opening Slide:GTEX-13OVJ-0726
#
# Level tiles for default level: (24, 14)
# ######### Closing Slide:slides/validation/lungs/GTEX-13OVJ-0726.svs
#
# ######### Opening Slide:GTEX-13JVG-1426
#
# Level tiles for default level: (27, 22)
# ######### Closing Slide:slides/validation/lungs/GTEX-13JVG-1426.svs
#
# ######### Opening Slide:GTEX-13FTY-0126
#
# Level tiles for default level: (23, 13)
# ######### Closing Slide:slides/validation/lungs/GTEX-13FTY-0126.svs
#
# ######### Opening Slide:GTEX-13N11-0326
#
# Level tiles for default level: (22, 28)
# ######### Closing Slide:slides/validation/lungs/GTEX-13N11-0326.svs
#
# ######### Opening Slide:GTEX-13FHP-0726
#
# Level tiles for default level: (22, 10)
# ######### Closing Slide:slides/validation/lungs/GTEX-13FHP-0726.svs
#
# ######### Opening Slide:GTEX-13D11-0326
#
# Level tiles for default level: (17, 9)
# ######### Closing Slide:slides/validation/lungs/GTEX-13D11-0326.svs
#
# ######### Opening Slide:GTEX-13FLV-0426
#
# Level tiles for default level: (23, 16)
# ######### Closing Slide:slides/validation/lungs/GTEX-13FLV-0426.svs
#
# ######### Opening Slide:GTEX-13FHO-1026
#
# Level tiles for default level: (26, 11)
# ######### Closing Slide:slides/validation/lungs/GTEX-13FHO-1026.svs
#
# ######### Opening Slide:GTEX-13FTZ-0526
#
# Level tiles for default level: (27, 16)
# ######### Closing Slide:slides/validation/lungs/GTEX-13FTZ-0526.svs
#
# ######### Opening Slide:GTEX-13NZA-1426
#
# Level tiles for default level: (29, 20)
# ######### Closing Slide:slides/validation/lungs/GTEX-13NZA-1426.svs
#
# ######### Opening Slide:GTEX-13NZ9-0926
#
# Level tiles for default level: (28, 14)
# ######### Closing Slide:slides/validation/lungs/GTEX-13NZ9-0926.svs
#
# ######### Opening Slide:GTEX-13FTX-0326
#
# Level tiles for default level: (22, 16)
# ######### Closing Slide:slides/validation/lungs/GTEX-13FTX-0326.svs
#
# []

# %%
invalid_liver_validation_slides = create_tiles("validation", "liver", 0.9)
print(invalid_liver_validation_slides)
# Out:
# num_slides: 20
# ######### Opening Slide:GTEX-13VXU-0926
#
# Level tiles for default level: (22, 17)
# ######### Closing Slide:slides/validation/livers/GTEX-13VXU-0926.svs
#
# ######### Opening Slide:GTEX-13SLX-1226
#
# Level tiles for default level: (22, 12)
# ######### Closing Slide:slides/validation/livers/GTEX-13SLX-1226.svs
#
# ######### Opening Slide:GTEX-12ZZZ-1326
#
# Level tiles for default level: (17, 10)
# ######### Closing Slide:slides/validation/livers/GTEX-12ZZZ-1326.svs
#
# ######### Opening Slide:GTEX-144GM-1326
#
# Level tiles for default level: (25, 15)
# ######### Closing Slide:slides/validation/livers/GTEX-144GM-1326.svs
#
# ######### Opening Slide:GTEX-131XH-0626
#
# Level tiles for default level: (30, 18)
# ######### Closing Slide:slides/validation/livers/GTEX-131XH-0626.svs
#
# ######### Opening Slide:GTEX-132NY-0926
#
# Level tiles for default level: (26, 13)
# ######### Closing Slide:slides/validation/livers/GTEX-132NY-0926.svs
#
# ######### Opening Slide:GTEX-139TU-0826
#
# Level tiles for default level: (24, 18)
# ######### Closing Slide:slides/validation/livers/GTEX-139TU-0826.svs
#
# ######### Opening Slide:GTEX-131YS-1626
#
# Level tiles for default level: (18, 9)
# ######### Closing Slide:slides/validation/livers/GTEX-131YS-1626.svs
#
# ['GTEX-13YAN-1626', 'GTEX-1445S-0926', 'GTEX-131XW-0926', 'GTEX-132Q8-1626', 'GTEX-13W46-1026', 'GTEX-144GL-1426', 'GTEX-13X6J-1826', 'GTEX-144FL-1326', 'GTEX-13X6I-1626', 'GTEX-13X6K-1126', 'GTEX-144GO-1126']

# %%
invalid_liver_train_slides = create_tiles("train", "liver", 0.9)
print(invalid_liver_train_slides)
# Out:
# num_slides: 136
# ######### Opening Slide:GTEX-13NZB-0626
#
# Level tiles for default level: (26, 16)
# ######### Closing Slide:slides/train/livers/GTEX-13NZB-0626.svs
#
# ######### Opening Slide:GTEX-11NUK-1226
#
# Level tiles for default level: (29, 19)
# ######### Closing Slide:slides/train/livers/GTEX-11NUK-1226.svs
#
# ######### Opening Slide:GTEX-13N2G-0926
#
# Level tiles for default level: (29, 14)
# ######### Closing Slide:slides/train/livers/GTEX-13N2G-0926.svs
#
# ######### Opening Slide:GTEX-11DXY-0526
#
# Level tiles for default level: (18, 22)
# ######### Closing Slide:slides/train/livers/GTEX-11DXY-0526.svs
#
# ######### Opening Slide:GTEX-12WSM-0726
#
# Level tiles for default level: (19, 10)
# ######### Closing Slide:slides/train/livers/GTEX-12WSM-0726.svs
#
# ######### Opening Slide:GTEX-11GSP-0626
#
# Level tiles for default level: (27, 20)
# ######### Closing Slide:slides/train/livers/GTEX-11GSP-0626.svs
#
# ######### Opening Slide:GTEX-13FTZ-0726
#
# Level tiles for default level: (27, 18)
# ######### Closing Slide:slides/train/livers/GTEX-13FTZ-0726.svs
#
# ######### Opening Slide:GTEX-13NYB-1026
#
# Level tiles for default level: (29, 18)
# ######### Closing Slide:slides/train/livers/GTEX-13NYB-1026.svs
#
# ######### Opening Slide:GTEX-12WSI-0226
#
# Level tiles for default level: (32, 23)
# ######### Closing Slide:slides/train/livers/GTEX-12WSI-0226.svs
#
# ######### Opening Slide:GTEX-13OW6-2626
#
# Level tiles for default level: (23, 12)
# ######### Closing Slide:slides/train/livers/GTEX-13OW6-2626.svs
#
# ######### Opening Slide:GTEX-13N11-0926
#
# Level tiles for default level: (26, 14)
# ######### Closing Slide:slides/train/livers/GTEX-13N11-0926.svs
#
# ######### Opening Slide:GTEX-139YR-0226
#
# Level tiles for default level: (28, 20)
# ######### Closing Slide:slides/train/livers/GTEX-139YR-0226.svs
#
# ######### Opening Slide:GTEX-13112-1426
#
# Level tiles for default level: (25, 17)
# ######### Closing Slide:slides/train/livers/GTEX-13112-1426.svs
#
# ######### Opening Slide:GTEX-13QJC-0726
#
# Level tiles for default level: (23, 17)
# ######### Closing Slide:slides/train/livers/GTEX-13QJC-0726.svs
#
# ######### Opening Slide:GTEX-11NV4-1326
#
# Level tiles for default level: (19, 15)
# ######### Closing Slide:slides/train/livers/GTEX-11NV4-1326.svs
#
# ######### Opening Slide:GTEX-11DXZ-0126
#
# Level tiles for default level: (26, 13)
# ######### Closing Slide:slides/train/livers/GTEX-11DXZ-0126.svs
#
# ######### Opening Slide:GTEX-13FTW-1126
#
# Level tiles for default level: (29, 22)
# ######### Closing Slide:slides/train/livers/GTEX-13FTW-1126.svs
#
# ######### Opening Slide:GTEX-13NZ9-1326
#
# Level tiles for default level: (28, 17)
# ######### Closing Slide:slides/train/livers/GTEX-13NZ9-1326.svs
#
# ######### Opening Slide:GTEX-13113-1326
#
# Level tiles for default level: (24, 16)
# ######### Closing Slide:slides/train/livers/GTEX-13113-1326.svs
#
# ######### Opening Slide:GTEX-11OF3-0726
#
# Level tiles for default level: (20, 18)
# ######### Closing Slide:slides/train/livers/GTEX-11OF3-0726.svs
#
# ######### Opening Slide:GTEX-13FLV-0326
#
# Level tiles for default level: (25, 14)
# ######### Closing Slide:slides/train/livers/GTEX-13FLV-0326.svs
#
# ######### Opening Slide:GTEX-131XE-0326
#
# Level tiles for default level: (23, 12)
# ######### Closing Slide:slides/train/livers/GTEX-131XE-0326.svs
#
# ######### Opening Slide:GTEX-12WSL-0226
#
# Level tiles for default level: (24, 14)
# ######### Closing Slide:slides/train/livers/GTEX-12WSL-0226.svs
#
# ######### Opening Slide:GTEX-13O3O-1826
#
# Level tiles for default level: (22, 17)
# ######### Closing Slide:slides/train/livers/GTEX-13O3O-1826.svs
#
# ######### Opening Slide:GTEX-13PVR-0126
#
# Level tiles for default level: (25, 13)
# ######### Closing Slide:slides/train/livers/GTEX-13PVR-0126.svs
#
# ######### Opening Slide:GTEX-11EQ9-0526
#
# Level tiles for default level: (16, 17)
# ######### Closing Slide:slides/train/livers/GTEX-11EQ9-0526.svs
#
# ['GTEX-16GPK-1926', 'GTEX-13FLW-0626', 'GTEX-15UF6-1326', 'GTEX-13CZV-1426', 'GTEX-11O72-0926', 'GTEX-11ILO-0926', 'GTEX-11ONC-0326', 'GTEX-16MT8-2126', 'GTEX-16XZZ-1526', 'GTEX-11EQ8-0626', 'GTEX-14PHX-0526', 'GTEX-16YQH-1126', 'GTEX-14PJM-1926', 'GTEX-15SZO-1226', 'GTEX-17EVP-1026', 'GTEX-13JUV-0726', 'GTEX-15DCZ-1526', 'GTEX-16NPX-1326', 'GTEX-15ER7-1826', 'GTEX-1313W-1726', 'GTEX-15SHW-0826', 'GTEX-13IVO-1526', 'GTEX-139UW-1026', 'GTEX-11DZ1-1326', 'GTEX-111FC-1226', 'GTEX-13S7M-1126', 'GTEX-1192W-0726', 'GTEX-17EVQ-0926', 'GTEX-14PJ2-1326', 'GTEX-18464-2026', 'GTEX-15EO6-1626', 'GTEX-13N1W-1326', 'GTEX-14PII-1926', 'GTEX-17HII-1026', 'GTEX-15SHU-1826', 'GTEX-15D1Q-1426', 'GTEX-13PDP-1826', 'GTEX-111VG-0826', 'GTEX-117XS-0926', 'GTEX-15DDE-1726', 'GTEX-15CHQ-0926', 'GTEX-11EMC-0326', 'GTEX-11GSO-0826', 'GTEX-13O3Q-1026', 'GTEX-13OW7-1326', 'GTEX-13FTY-0826', 'GTEX-13PLJ-1026', 'GTEX-12ZZX-1526', 'GTEX-13QJ3-2026', 'GTEX-11GS4-0926', 'GTEX-14PJO-1726', 'GTEX-15RJE-1126', 'GTEX-13CIG-1426', 'GTEX-15TU5-2126', 'GTEX-17JCI-1926', 'GTEX-13G51-0626', 'GTEX-1117F-1126', 'GTEX-14PN4-1126', 'GTEX-113JC-0426', 'GTEX-13FXS-1426', 'GTEX-11EI6-0926', 'GTEX-12ZZY-2026', 'GTEX-17F96-1226', 'GTEX-12ZZW-1426', 'GTEX-17MF6-1126', 'GTEX-14XAO-0226', 'GTEX-15DYW-1326', 'GTEX-1314G-0526', 'GTEX-15EOM-1126', 'GTEX-13FHO-1126', 'GTEX-15G19-1226', 'GTEX-13NZ8-1826', 'GTEX-14LZ3-0826', 'GTEX-11DYG-1726', 'GTEX-16MT9-2126', 'GTEX-13OW8-0726', 'GTEX-13CF2-0626', 'GTEX-18465-1626', 'GTEX-13OW5-1226', 'GTEX-15UKP-1026', 'GTEX-13SLW-1426', 'GTEX-16NPV-1726', 'GTEX-117YW-0626', 'GTEX-14PQA-1326', 'GTEX-13OVH-0926', 'GTEX-183WM-1226', 'GTEX-15D79-2326', 'GTEX-13NYS-1226', 'GTEX-13QIC-0526', 'GTEX-15RJ7-2026', 'GTEX-13JVG-1526', 'GTEX-15SKB-2126', 'GTEX-13O3P-1726', 'GTEX-15UF7-0426', 'GTEX-13FHP-1426', 'GTEX-15DCD-0826', 'GTEX-13OVL-0726', 'GTEX-13NZA-1626', 'GTEX-16Z82-1426', 'GTEX-15CHS-1426', 'GTEX-13RTJ-1226', 'GTEX-13PL6-1226', 'GTEX-18A66-2026', 'GTEX-14PHW-1726', 'GTEX-13NYC-0526']

# %%
invalid_lung_train_slides = create_tiles("train", "lung", 0.8)
print(invalid_lung_train_slides)
# Out:
# num_slides: 136
# ######### Opening Slide:GTEX-131YS-0926
#
# Level tiles for default level: (21, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-131YS-0926.svs
#
# ######### Opening Slide:GTEX-11P7K-0326
#
# Level tiles for default level: (21, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-11P7K-0326.svs
#
# ######### Opening Slide:GTEX-13RTJ-1126
#
# Level tiles for default level: (28, 20)
# ######### Closing Slide:slides/train/lungs/GTEX-13RTJ-1126.svs
#
# ######### Opening Slide:GTEX-1477Z-0626
#
# Level tiles for default level: (23, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-1477Z-0626.svs
#
# ######### Opening Slide:GTEX-145LU-0526
#
# Level tiles for default level: (23, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-145LU-0526.svs
#
# ######### Opening Slide:GTEX-11ZTS-1226
#
# Level tiles for default level: (26, 12)
# ######### Closing Slide:slides/train/lungs/GTEX-11ZTS-1226.svs
#
# ######### Opening Slide:GTEX-13OW5-0726
#
# Level tiles for default level: (23, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-13OW5-0726.svs
#
# ######### Opening Slide:GTEX-145MH-0626
#
# Level tiles for default level: (17, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-145MH-0626.svs
#
# ######### Opening Slide:GTEX-1313W-0926
#
# Level tiles for default level: (24, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-1313W-0926.svs
#
# ######### Opening Slide:GTEX-144GM-0126
#
# Level tiles for default level: (24, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-144GM-0126.svs
#
# ######### Opening Slide:GTEX-13CF3-0426
#
# Level tiles for default level: (22, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-13CF3-0426.svs
#
# ######### Opening Slide:GTEX-13YAN-1026
#
# Level tiles for default level: (21, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-13YAN-1026.svs
#
# ######### Opening Slide:GTEX-12WSG-0326
#
# Level tiles for default level: (21, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSG-0326.svs
#
# ######### Opening Slide:GTEX-13VXT-1426
#
# Level tiles for default level: (23, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-13VXT-1426.svs
#
# ######### Opening Slide:GTEX-139T6-0426
#
# Level tiles for default level: (23, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-139T6-0426.svs
#
# ######### Opening Slide:GTEX-11UD2-0726
#
# Level tiles for default level: (26, 22)
# ######### Closing Slide:slides/train/lungs/GTEX-11UD2-0726.svs
#
# ######### Opening Slide:GTEX-12584-1426
#
# Level tiles for default level: (22, 12)
# ######### Closing Slide:slides/train/lungs/GTEX-12584-1426.svs
#
# ######### Opening Slide:GTEX-11NSD-0326
#
# Level tiles for default level: (27, 20)
# ######### Closing Slide:slides/train/lungs/GTEX-11NSD-0326.svs
#
# ######### Opening Slide:GTEX-11ZTT-0626
#
# Level tiles for default level: (19, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-11ZTT-0626.svs
#
# ######### Opening Slide:GTEX-145MF-0726
#
# Level tiles for default level: (24, 19)
# ######### Closing Slide:slides/train/lungs/GTEX-145MF-0726.svs
#
# ######### Opening Slide:GTEX-13QJ3-1026
#
# Level tiles for default level: (21, 11)
# ######### Closing Slide:slides/train/lungs/GTEX-13QJ3-1026.svs
#
# ######### Opening Slide:GTEX-13113-0426
#
# Level tiles for default level: (21, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-13113-0426.svs
#
# ######### Opening Slide:GTEX-12WSE-0826
#
# Level tiles for default level: (23, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSE-0826.svs
#
# ######### Opening Slide:GTEX-11ZUS-0126
#
# Level tiles for default level: (23, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-11ZUS-0126.svs
#
# ######### Opening Slide:GTEX-11NV4-1126
#
# Level tiles for default level: (20, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-11NV4-1126.svs
#
# ######### Opening Slide:GTEX-13QJC-0526
#
# Level tiles for default level: (28, 19)
# ######### Closing Slide:slides/train/lungs/GTEX-13QJC-0526.svs
#
# ######### Opening Slide:GTEX-12WSJ-0226
#
# Level tiles for default level: (28, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSJ-0226.svs
#
# ######### Opening Slide:GTEX-13VXU-2726
#
# Level tiles for default level: (24, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-13VXU-2726.svs
#
# ######### Opening Slide:GTEX-13U4I-1426
#
# Level tiles for default level: (24, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-13U4I-1426.svs
#
# ######### Opening Slide:GTEX-1399U-0826
#
# Level tiles for default level: (23, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-1399U-0826.svs
#
# ######### Opening Slide:GTEX-1339X-0626
#
# Level tiles for default level: (27, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-1339X-0626.svs
#
# ######### Opening Slide:GTEX-12ZZW-0926
#
# Level tiles for default level: (24, 20)
# ######### Closing Slide:slides/train/lungs/GTEX-12ZZW-0926.svs
#
# ######### Opening Slide:GTEX-11WQC-0626
#
# Level tiles for default level: (20, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-11WQC-0626.svs
#
# ######### Opening Slide:GTEX-1211K-0826
#
# Level tiles for default level: (24, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-1211K-0826.svs
#
# ######### Opening Slide:GTEX-11I78-0126
#
# Level tiles for default level: (23, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-11I78-0126.svs
#
# ######### Opening Slide:GTEX-13FH7-1726
#
# Level tiles for default level: (22, 12)
# ######### Closing Slide:slides/train/lungs/GTEX-13FH7-1726.svs
#
# ######### Opening Slide:GTEX-1212Z-1026
#
# Level tiles for default level: (28, 19)
# ######### Closing Slide:slides/train/lungs/GTEX-1212Z-1026.svs
#
# ######### Opening Slide:GTEX-132QS-0726
#
# Level tiles for default level: (23, 12)
# ######### Closing Slide:slides/train/lungs/GTEX-132QS-0726.svs
#
# ######### Opening Slide:GTEX-144GN-0426
#
# Level tiles for default level: (27, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-144GN-0426.svs
#
# ######### Opening Slide:GTEX-11TUW-0526
#
# Level tiles for default level: (27, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-11TUW-0526.svs
#
# ######### Opening Slide:GTEX-11OF3-1126
#
# Level tiles for default level: (17, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-11OF3-1126.svs
#
# ######### Opening Slide:GTEX-13OW6-0826
#
# Level tiles for default level: (24, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-13OW6-0826.svs
#
# ######### Opening Slide:GTEX-12696-1026
#
# Level tiles for default level: (20, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-12696-1026.svs
#
# ######### Opening Slide:GTEX-13OVL-0626
#
# Level tiles for default level: (26, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-13OVL-0626.svs
#
# ######### Opening Slide:GTEX-11PRG-0926
#
# Level tiles for default level: (28, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-11PRG-0926.svs
#
# ######### Opening Slide:GTEX-133LE-0526
#
# Level tiles for default level: (25, 19)
# ######### Closing Slide:slides/train/lungs/GTEX-133LE-0526.svs
#
# ######### Opening Slide:GTEX-11WQK-1226
#
# Level tiles for default level: (25, 22)
# ######### Closing Slide:slides/train/lungs/GTEX-11WQK-1226.svs
#
# ######### Opening Slide:GTEX-145LT-0326
#
# Level tiles for default level: (23, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-145LT-0326.svs
#
# ######### Opening Slide:GTEX-145MN-0926
#
# Level tiles for default level: (23, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-145MN-0926.svs
#
# ######### Opening Slide:GTEX-12WSK-0826
#
# Level tiles for default level: (21, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSK-0826.svs
#
# ######### Opening Slide:GTEX-13QBU-0726
#
# Level tiles for default level: (24, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-13QBU-0726.svs
#
# ######### Opening Slide:GTEX-11LCK-0426
#
# Level tiles for default level: (27, 19)
# ######### Closing Slide:slides/train/lungs/GTEX-11LCK-0426.svs
#
# ######### Opening Slide:GTEX-131XF-1026
#
# Level tiles for default level: (25, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-131XF-1026.svs
#
# ######### Opening Slide:GTEX-12KS4-0726
#
# Level tiles for default level: (25, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-12KS4-0726.svs
#
# ######### Opening Slide:GTEX-12BJ1-1026
#
# Level tiles for default level: (22, 19)
# ######### Closing Slide:slides/train/lungs/GTEX-12BJ1-1026.svs
#
# ######### Opening Slide:GTEX-11TT1-1626
#
# Level tiles for default level: (25, 20)
# ######### Closing Slide:slides/train/lungs/GTEX-11TT1-1626.svs
#
# ######### Opening Slide:GTEX-131XE-0726
#
# Level tiles for default level: (20, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-131XE-0726.svs
#
# ######### Opening Slide:GTEX-146FQ-0926
#
# Level tiles for default level: (21, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-146FQ-0926.svs
#
# ######### Opening Slide:GTEX-131XH-0426
#
# Level tiles for default level: (29, 19)
# ######### Closing Slide:slides/train/lungs/GTEX-131XH-0426.svs
#
# ######### Opening Slide:GTEX-12WSI-0826
#
# Level tiles for default level: (21, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSI-0826.svs
#
# ######### Opening Slide:GTEX-131XW-1126
#
# Level tiles for default level: (23, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-131XW-1126.svs
#
# ######### Opening Slide:GTEX-13S86-0626
#
# Level tiles for default level: (21, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-13S86-0626.svs
#
# ######### Opening Slide:GTEX-11NUK-0826
#
# Level tiles for default level: (21, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-11NUK-0826.svs
#
# ######### Opening Slide:GTEX-12ZZY-0926
#
# Level tiles for default level: (22, 18)
# ######### Closing Slide:slides/train/lungs/GTEX-12ZZY-0926.svs
#
# ######### Opening Slide:GTEX-13111-0426
#
# Level tiles for default level: (22, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-13111-0426.svs
#
# ######### Opening Slide:GTEX-13OW8-1726
#
# Level tiles for default level: (17, 9)
# ######### Closing Slide:slides/train/lungs/GTEX-13OW8-1726.svs
#
# ######### Opening Slide:GTEX-12WSL-1026
#
# Level tiles for default level: (27, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSL-1026.svs
#
# ######### Opening Slide:GTEX-11O72-1326
#
# Level tiles for default level: (22, 21)
# ######### Closing Slide:slides/train/lungs/GTEX-11O72-1326.svs
#
# ######### Opening Slide:GTEX-146FH-1226
#
# Level tiles for default level: (26, 12)
# ######### Closing Slide:slides/train/lungs/GTEX-146FH-1226.svs
#
# ######### Opening Slide:GTEX-13PL7-1726
#
# Level tiles for default level: (21, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-13PL7-1726.svs
#
# ######### Opening Slide:GTEX-144GO-0226
#
# Level tiles for default level: (31, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-144GO-0226.svs
#
# ######### Opening Slide:GTEX-1399S-1726
#
# Level tiles for default level: (17, 10)
# ######### Closing Slide:slides/train/lungs/GTEX-1399S-1726.svs
#
# ######### Opening Slide:GTEX-11P81-0226
#
# Level tiles for default level: (19, 11)
# ######### Closing Slide:slides/train/lungs/GTEX-11P81-0226.svs
#
# ######### Opening Slide:GTEX-12WSN-0626
#
# Level tiles for default level: (21, 15)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSN-0626.svs
#
# ######### Opening Slide:GTEX-145MO-1326
#
# Level tiles for default level: (20, 16)
# ######### Closing Slide:slides/train/lungs/GTEX-145MO-1326.svs
#
# ######### Opening Slide:GTEX-12WSD-0826
#
# Level tiles for default level: (25, 11)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSD-0826.svs
#
# ######### Opening Slide:GTEX-145LS-1226
#
# Level tiles for default level: (24, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-145LS-1226.svs
#
# ######### Opening Slide:GTEX-13PVQ-0926
#
# Level tiles for default level: (26, 14)
# ######### Closing Slide:slides/train/lungs/GTEX-13PVQ-0926.svs
#
# ######### Opening Slide:GTEX-132NY-1226
#
# Level tiles for default level: (23, 13)
# ######### Closing Slide:slides/train/lungs/GTEX-132NY-1226.svs
#
# ######### Opening Slide:GTEX-12WSA-1026
#
# Level tiles for default level: (21, 17)
# ######### Closing Slide:slides/train/lungs/GTEX-12WSA-1026.svs
#
# ['GTEX-1399Q-0726', 'GTEX-12WS9-1026', 'GTEX-1211K-5004', 'GTEX-13PL6-2426', 'GTEX-13X6K-1626', 'GTEX-11ZVC-0226', 'GTEX-145MI-0726', 'GTEX-13W46-1426', 'GTEX-11TTK-0926', 'GTEX-132AR-0926', 'GTEX-13PDP-0826', 'GTEX-11ZU8-1026', 'GTEX-12WSB-0826', 'GTEX-13CZU-0326', 'GTEX-13W3W-0326', 'GTEX-12WSC-0726', 'GTEX-132Q8-0926', 'GTEX-1445S-1426', 'GTEX-13X6I-0826', 'GTEX-13S7M-2126', 'GTEX-13112-0826', 'GTEX-139TS-1326', 'GTEX-13SLW-1226', 'GTEX-131XF-5010', 'GTEX-13113-5004', 'GTEX-145MG-1426', 'GTEX-12ZZZ-1126', 'GTEX-12C56-5001', 'GTEX-11ONC-0826', 'GTEX-12ZZX-0926', 'GTEX-139D8-1726', 'GTEX-12WSN-5004', 'GTEX-13CZV-0626', 'GTEX-11XUK-0326', 'GTEX-14753-0826', 'GTEX-12WSF-0726', 'GTEX-144GL-1126', 'GTEX-145ME-0226', 'GTEX-13OW7-0926', 'GTEX-11ZTT-5002', 'GTEX-12WSG-5004', 'GTEX-12C56-0126', 'GTEX-13PLJ-0626', 'GTEX-145ME-5001', 'GTEX-13QIC-0326', 'GTEX-1314G-5004', 'GTEX-1314G-0326', 'GTEX-13X6J-1026', 'GTEX-1399T-2326', 'GTEX-13CIG-1126', 'GTEX-13SLX-0626', 'GTEX-13OVK-0126', 'GTEX-144FL-1626']
